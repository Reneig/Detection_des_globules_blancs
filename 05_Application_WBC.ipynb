# %% [markdown]
# # 🖼️ 05 - Application WBC - Interface Graphique
#
# ## **Développement d'une Application Graphique avec PyQt5**
#
# Ce projet a pour but de créer une application graphique interactive pour utiliser un modèle de **Réseau de Neurones Convolutionnel (CNN)**, dédié à la détection des globules blancs. L'application permet de :
# - **Charger un modèle CNN** au format `.h5` ;
# - **Sélectionner et afficher des images** depuis un répertoire ;
# - **Appliquer une prédiction CNN** et afficher les résultats visuellement sur l'image sélectionnée.
#
# L'interface graphique est construite avec **PyQt5** (et l'application peut être empaquetée en exécutable grâce à **PyInstaller**).
#
# ---
#
# ## **Concepts Clés pour PyQt5**
#
# ### **1️⃣ Structure de Base d'une Application PyQt5**
# Une application PyQt5 repose sur une structure simple et bien définie :
# 1. **Initialisation** : Crée une instance de `QApplication`, essentielle pour l'exécution de l'application.
# 2. **Interface Utilisateur** : Déclare la fenêtre principale, les widgets comme `QPushButton`, `QLabel`, `QListWidget`, et les layouts tels que `QVBoxLayout`, `QHBoxLayout`.
# 3. **Signaux (événements) et Slots (fonctions qui réagissent à ces événements)** : Les actions de l'utilisateur sont liées à des fonctions Python via le mécanisme des signaux et slots.
# 4. **Boucle d'Événements** : L’application entre en mode interactif grâce à `app.exec_()` et reste en attente des actions utilisateur.
#
# ---
#
# ### **2️⃣ Widgets et Layouts**
#
# #### **Widgets : Composants Visuels**
# Les **widgets** sont les éléments visuels de l'interface qui interagissent avec l'utilisateur. Voici quelques exemples de widgets utilisés dans cette application :
# - `QPushButton` : Crée un bouton interactif, par exemple pour ouvrir un dossier d'images ou charger un modèle.
# - `QListWidget` : Affiche une liste d'images sélectionnables à partir du répertoire.
# - `QLabel` : Affiche soit du texte, soit des images (comme l'image sélectionnée ou le résultat de la prédiction).
#
# #### **Layouts : Organiser les Widgets**
# Les **layouts** sont responsables de la disposition des widgets dans la fenêtre. Deux principaux types de layouts sont utilisés :
# - `QVBoxLayout` : Dispose les widgets verticalement (par exemple, les boutons et l'affichage de l'image).
# - `QHBoxLayout` : Dispose les widgets horizontalement (utilisé ici pour placer les boutons côte à côte).
#
# > **Exemple d’ajout d’un widget dans un layout :**
# > ```python
# > layout = QVBoxLayout()
# > button = QPushButton("Cliquez ici")
# > layout.addWidget(button)
# > ```
#
# ---
#
# ### **3️⃣ Signaux et Slots : Interaction Utilisateur**
#
# Les **signaux** sont des événements (par exemple, un clic sur un bouton), et les **slots** sont les fonctions qui réagissent à ces événements.
#
# Dans cette application, chaque interaction utilisateur, comme cliquer sur un bouton, est connectée à une fonction spécifique via un signal :
#
# > **Exemple :**
# > ```python
# > button.clicked.connect(on_button_click)
# > ```
# > Lorsque l'utilisateur clique sur `button`, la fonction `on_button_click` est exécutée.
#
# Dans l’application WBC :
# - **`choose_folder_button`** ouvre une boîte de dialogue pour sélectionner un dossier d'images.
# - **`choose_model_button`** charge un modèle `.h5`.
# - **`predict_button`** applique la prédiction du modèle CNN sur l'image sélectionnée.
#
# ---
#
# ### **4️⃣ Gestion des Fichiers et Répertoires**
#
# #### **Sélection d’un Répertoire**
# L'application permet à l'utilisateur de choisir un répertoire contenant les images à traiter. Cela est réalisé avec `QFileDialog.getExistingDirectory()` :
#
# > **Code de sélection de répertoire :**
# > ```python
# > folder = QFileDialog.getExistingDirectory(self, 'Choisir un répertoire')
# > ```
#
# #### **Chargement d’un Fichier Modèle**
# L'utilisateur peut charger un fichier modèle `.h5` en cliquant sur un bouton et en sélectionnant un fichier via la boîte de dialogue :
#
# > **Code de chargement du modèle :**
# > ```python
# > model_file, _ = QFileDialog.getOpenFileName(self, 'Choisir un modèle', '', 'Fichiers H5 (*.h5)')
# > ```
#
# ---
#
# ## **Architecture de l'Application**
#
# L'application est composée de deux classes principales : `ImageLister` et `PredictThread`.
#
# ### **Classe `ImageLister`**
# La classe **`ImageLister`** est responsable de l'interface graphique et des interactions avec l'utilisateur. Elle gère :
# - La sélection du répertoire d'images (`choose_folder_button`).
# - Le chargement du modèle CNN (`choose_model_button`).
# - La liste des images disponibles dans le répertoire sélectionné (`image_list_widget`).
# - L'affichage de l'image sélectionnée avant et après la prédiction.
#
# #### **Interaction avec `PredictThread`**
# Lorsqu'une image est sélectionnée et que l'utilisateur clique sur le bouton de prédiction, un thread est lancé via **`PredictThread`** pour exécuter la prédiction sans bloquer l'interface utilisateur.
#
# ---
#
# ### **Classe `PredictThread`**
# La classe **`PredictThread`** effectue la prédiction sur l'image sélectionnée. Elle travaille en arrière-plan pour éviter de figer l'interface, en utilisant un thread séparé :
# 1. Elle charge et pré-traite l'image sélectionnée.
# 2. Elle applique le modèle CNN pour effectuer la prédiction.
# 3. Elle renvoie le résultat via un signal `prediction_done` pour l'afficher dans l'interface graphique.
#
# > **Interaction avec `ImageLister`** :
# > Une fois la prédiction effectuée, le résultat est envoyé à `ImageLister` pour être affiché. Ce processus permet de visualiser l'image avec la prédiction superposée.
#
# ---
#
# ## **Principaux Composants et Fonctionnalités**
#
# 1. **Chargement des Images** :
#    - Le dossier d'images est choisi via une boîte de dialogue.
#    - Les images sont affichées dans une liste sous forme de `QListWidget`.
#    - L'utilisateur peut cliquer sur une image pour la visualiser dans un `QLabel`.
#
# 2. **Chargement du Modèle CNN** :
#    - Le modèle est sélectionné au format `.h5` via une boîte de dialogue.
#    - Une fois chargé, le modèle est prêt pour la prédiction.
#
# 3. **Prédiction** :
#    - Lorsque l'utilisateur clique sur `Apply Pred.`, le modèle est appliqué à l'image sélectionnée dans un thread séparé.
#    - Le résultat est une image avec les zones détectées mises en surbrillance (comme un masque vert), et est affichée dans le `QLabel`.
#
# ---
#
# ## **Exemple de Code de Lancement de l'Application**
#
# ```python
# if __name__ == '__main__':
#     app = QApplication(sys.argv)
#     app.setStyleSheet("""...""")  # Définition du style sombre pour l'application
#     window = ImageLister()
#     window.show()
#     sys.exit(app.exec_())

# %% [markdown]
# ## **Compilation du fichier Python en Exécutable Windows**
#
# - 1/ Créez un dossier **Application_DeepLearning** dans le dossier projet et déplacez-y le fichier `App_WBC.py` pour éviter de polluer le dossier principal, puis placez vous dans ce dossier avec la commande : **cd Application_DeepLearning**
# - 2/ Créez un environnement virtuel dédié pour n'inclure que les librairies nécessaires à l'exécution de l'application, ce qui réduit la taille de l'exécutable.
# ```bash
#   python -m venv env_app
#   .\env_app\Script\Activate.ps1
#   ```
#
# - 3/ Créer un fichier requirements_app.txt, et copiez le contenu la liste de ces librairies à installer avec PIP:
# ```bash
# PyQt5==5.15.11
# numpy==1.26.4
# tensorflow==2.14.0
# opencv-python==4.10.0.84
# pillow==11.1.0
# pyinstaller==5.13.2
# ```
# - 5/ Installer les librairies :
# ```bash
# pip install -r requirements_app.txt
# ```
# - 5/ Puis compiler le fichier python la commande suivante dans le dossier **Application_DeepLearning** :
#
# ```bash
# pyinstaller --onefile --noconsole --hidden-import=PyQt5.QtCore --hidden-import=PyQt5.QtGui --hidden-import=PyQt5.QtWidgets --hidden-import=tensorflow --hidden-import=keras App_WBC.py
