# %% [markdown]
# # 🖼️ 01 - Annotation des Images avec LabelMe
#
# Dans cette étape, vous apprendrez à annoter des images pour identifier les objets d'intérêt, en l'occurrence les globules blancs. **Les annotations des images présentes dans le dossier `IMG` ont déjà été effectuées, mais ce tutoriel vous expliquera comment utiliser l'outil LabelMe pour réaliser ou ajuster des annotations.**
#
# Ces annotations ont été réalisées pour faciliter l'entraînement du modèle de segmentation d'images. Si vous devez retravailler les annotations existantes ou en créer de nouvelles, ce guide vous fournira les étapes nécessaires.
#
# **Prérequis :**
# - **LabelMe** est déjà installé dans l'environnement Python et prêt à être utilisé.
# - L'environnement virtuel est déjà activé.
#
# ## Étapes pour Annoter une Image
#
# ### 1. Lancer LabelMe
#
# Une fois l'environnement activé, vous pouvez démarrer l'interface de **LabelMe** en utilisant la commande suivante dans votre terminal ou votre interface de développement :
#
# ```bash
# labelme
# ```
# ### 2. Lancer LabelMe
#
# Cliquez sur l'Onglet **"Open Dir"** pour ouvrir le dossier contenant les images à annoter.
# La première image du repertoire va alors s'afficher au centre de l'interface. Et vous aurez la liste de toutes les images retrouvées avec leur chemin d'accès, dans la fênetre **"File List"**. Une image dont l'annotation a deja été réalisé va avoir une case remplie.
#
# ### 3. Débuter l'Annotation des Images avec LabelMe
#
# L'annotation des images est une étape cruciale pour entraîner des modèles de machine learning. Voici un guide étape par étape pour commencer l'annotation à l'aide de **LabelMe**.
#
# #### 3.1 Créer des Polygones pour l'Annotation
#
# 1. **Sélectionner l'outil d'annotation** :
#    - Dans le menu du haut, cliquez sur l'onglet **"Create Polygons"**. Cela vous permet de dessiner des polygones autour des objets que vous souhaitez annoter.
#
# 2. **Dessiner le polygone autour de l'objet** :
#    - Cliquez pour commencer le tracé du polygone autour de l'objet à annoter (par exemple, un globule blanc). Pour ce faire, cliquez **gauche** à chaque coin de l'objet, et relâchez le bouton lorsque vous souhaitez ajouter un point.
#    - Pour fermer le polygone, cliquez sur le **premier point** du tracé.
#
# 3. **Ajuster la précision de l'annotation** :
#    - Si l'objet que vous souhaitez annoter est petit ou difficile à voir, vous pouvez **zoomer** pour plus de précision. Utilisez la combinaison de touches **CTRL + Scroll Avant** pour zoomer sur l'image et ajuster l'annotation.
#
# #### 3.2 Ajouter un Label à l'Annotation
#
# 1. **Saisir un label pour l'objet** :
#    - Une fenêtre pop-up apparaîtra automatiquement après avoir terminé le tracé du polygone. Cette fenêtre vous permettra de spécifier un **label** pour l'objet annoté (par exemple, **globule_blanc**).
#
# 2. **Assigner un ID et une description** :
#    - Vous aurez également la possibilité de spécifier un **ID** (par exemple, **ID = 1**) et d'ajouter une **description** pour l'annotation. Si vous n'avez qu'un seul type d'objet à annoter, vous n'aurez qu'un label à enregistrer. Sinon, vous pourrez choisir un label existant ou en créer un nouveau.
#
#    - Dans notre cas d'étude, nous n'avons qu'un seul label, **"globule_blanc"**, avec l'ID **1**.
#
# 3. **Visualisation des labels existants** :
#    - Une fois que vous avez créé un label, celui-ci apparaîtra dans la fenêtre **"Polygon Labels"**. Vous verrez alors une liste des labels, par exemple : **globule_blanc(1)**.
#    - Lors de l'annotation d'un autre objet, vous pourrez soit choisir un label existant dans la liste, soit en ajouter un nouveau.
#
# #### 3.3 Édition des Polygones pour Corriger une Annotation
#
# 1. **Sélectionner l'outil d'édition** :
#    - Si vous avez besoin de corriger ou ajuster une annotation après l'avoir réalisée, cliquez sur l'onglet **"Edit Polygons"** dans le menu du haut.
#
# 2. **Modifier l'annotation existante** :
#    - Une fois l'outil **"Edit Polygons"** activé, cliquez sur le polygone que vous souhaitez modifier. Vous pouvez alors déplacer les points du polygone, en cliquant et en maintenant enfoncé un point existant pour le faire glisser à un nouvel emplacement.
#    - Si vous devez ajouter un nouveau point, cliquez sur la ligne du polygone à l'endroit où vous souhaitez ajouter le point.
#    - Si vous devez supprimer un point, cliquez dessus pour le retirer.
#
# 3. **Finaliser les modifications** :
#    - Une fois que vous avez terminé vos ajustements, cliquez à nouveau sur l'outil **"Save"** pour sauvegarder les modifications dans le fichier d'annotation.
#
# #### 3.4 Sauvegarder l'Annotation
#
# 1. **Sauvegarder l'annotation** :
#    - Une fois que vous avez terminé toutes vos annotations sur l'image, cliquez sur l'onglet **"Save"** dans le menu du haut. Cela vous permettra de sauvegarder vos annotations sous forme de fichier **JSON**.
#
# 2. **Choisir le répertoire de sauvegarde** :
#    - Une fenêtre de dialogue s'affichera pour vous demander où vous souhaitez enregistrer le fichier JSON contenant vos annotations.
#    - Par défaut, **LabelMe** enregistre les annotations dans le même répertoire que l'image annotée. Cela facilite l'organisation des fichiers.
#
#    **Conseil** : Il est recommandé de conserver les fichiers d'annotations et les images dans le même dossier, afin de faciliter la gestion des données et de vous assurer que chaque image annotée soit bien associée à son fichier d'annotation.
#
# 3. **Vérification de la sauvegarde** :
#    - Vous pouvez consulter la fenêtre **"File list"** pour vérifier quelles images ont été annotées. Les images annotées seront marquées comme traitées, vous permettant de suivre votre progression.
#
# ---
#
# ### Conseils supplémentaires :
#
# - **Répéter l'annotation** : Si vous avez plusieurs images à annoter, vous pouvez répéter ces étapes pour chaque image du dataset.
# - **Reprise des annotations** : Si vous devez reprendre une annotation précédente, ouvrez simplement l'image dans **LabelMe**, modifiez ou ajustez les polygones comme nécessaire, puis sauvegardez à nouveau.
# - **Précision** : Prenez votre temps pour vous assurer que les polygones sont tracés avec précision autour des objets d'intérêt (globules blancs, par exemple), car la qualité des annotations impactera directement la performance du modèle d'apprentissage.
