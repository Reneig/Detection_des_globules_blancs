# %% [markdown]
# # Projet 01, Deep Learning : Détection de globules blanc
#
# ### Les Étapes du Projet sous 4 Jupyter
# | **Étape**                             | **Description**                                                                                                                                                      | **Compétences acquises**                                                                                             | **Jupyter Notebook**                   |
# |---------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------|----------------------------------------|
# | **💡 Formation Express Python**       | Formation Express pour prendre en main le langage Python, ses bases, ses structures de données, la POO (Programmation Orientée Objet) et le fonctionnement général du langage. | Comprendre les bases du langage Python, les structures de données (listes, dictionnaires, etc.), et les concepts de POO. | `00_Formation_Express_Python.ipynb`    |
# | **1️⃣ Annotation des Images**          | Annotation des zones contenant des globules blancs dans les images microscopiques.                                                                                   | Apprendre à travailler avec des données étiquetées, comprendre les processus d'annotation d'images.                  | `01_Annotation_images.ipynb`            |
# | **2️⃣ Création des Masques**           | Génération de masques binaires pour identifier les globules blancs.                                                                                                 | Maîtriser la création de masques pour la segmentation d'images.                                                     | `02_Creation_masques.ipynb`            |
# | **3️⃣ Développement du Modèle CNN + Calcul** | Construction du modèle CNN pour segmenter les globules blancs. Calcul des courbes de perte et de précision pour analyser les performances du modèle en temps réel.   | Conception, entraînement et évaluation du modèle CNN, analyse des courbes d'entraînement et ajustement des hyperparamètres. | `03_WBC_model_CNN.ipynb`               |
# | **4️⃣ Évaluation et Test du Modèle**   | Évaluation finale du modèle en testant ses performances sur des données de validation, et ajustement final des hyperparamètres pour optimiser les résultats.          | Test du modèle sur des jeux de données de validation, analyse des résultats et ajustement des paramètres finaux.        | `04_Evaluation_model.ipynb`            |
# | **5️⃣ Application Desktop Deep Learning** | Création d'une application desktop utilisant le modèle Deep Learning pour la détection des globules blancs.                                                           | Développement d'une interface graphique pour l'application de Deep Learning avec une intégration fluide du modèle.   | `05_Application_WBC.ipynb`             |
# | **6️⃣ BONUS - TensorBoard**            | Introduction à l'utilisation de TensorBoard pour la visualisation des performances du modèle et l'analyse des métriques.                                              | Apprendre à utiliser TensorBoard pour visualiser les courbes d'entraînement, les pertes et les performances du modèle. | `BONUS_06_Tensorboard.ipynb`          |

# %% [markdown]
# # 🛠️ **Préparation de l'Environnement de Travail**
#
# ### 📝 **Description du Jeu d'Images**
# Ce jeu de données contient **1141 images de frottis sanguins** provenant de **50 patients non infectés par le paludisme**.
#
# ---
#
# ### 📂 **Structure des Fichiers**
# - Les images sont contenues dans le dossier **IMG**, accompagnées des fichiers d'annotations **JSON**. Veuillez dézipper le fichier zip suivant :
#   `Proj_01_WBC_DeepLearning.zip`
#
# ```bash
# Proj_DeepLearning/
# ├── IMG/                                # Dossier contenant les images et annotations JSON
# ├── Masks/                              # Dossier généré automatiquement pour contenir les masques (images binaires)
# ├── TF206_15_27SA/                      # Dossier images d'un patient pour évaluer le modèle (après l'entraînement)
# ├── Evaluate_and_Analyze/               # Dossier généré automatiquement pour contenir les resultats du calcul (+ logs)
# ├── requirements.txt                    # Fichier des dépendances nécessaires au projet
# ├── Guide_Projet_01_WBC_DL.ipynb        # Guide du projet pour comprendre la démarche
# ├── 00_Formation_Express_Python.ipynb   # Formation express en Python (les bases minimales)
# ├── 01_Annotation_images.ipynb          # Notebook pour annoter les images
# ├── 02_Creation_masques.ipynb           # Notebook pour créer les masques des images
# ├── 03_WBC_model_CNN.ipynb              # Notebook pour la création du modèle CNN WBC
# ├── 04_Evaluation_model.ipynb           # Notebook pour l'évaluation du modèle
# ├── 05_Application_WBC.ipynb            # Notebook pour la création d'une application bureau deep learning
# └── 06_BONUS_Tensorboard.ipynb          # Notebook pour l'utilisation de tensorboard
#
# ```
#
# ### **©️ Droits d'Auteur et Conditions d'Utilisation**
#
# Ce contenu de formation, incluant mais non limité aux notebooks, vidéos, et tout matériel associé (ci-après dénommé **"le Contenu"**), ainsi que le jeu de données d'images utilisé lors de ce projet de formation, est protégé par les lois sur les droits d'auteur.
#
# **Usage Personnel et Éducatif Exclusif**
# Le Contenu est fourni exclusivement pour votre usage personnel et éducatif. Toute autre utilisation, y compris mais non limitée à la copie, la distribution, la modification, ou la republication du Contenu, est strictement interdite sans l'autorisation écrite préalable de l'auteur.
#
# **Interdiction de Diffusion**
# Vous **n'êtes pas autorisé(e)** à partager, publier ou diffuser le Contenu, en tout ou en partie, sous quelque forme que ce soit, en ligne ou hors ligne, sans l'accord explicite de l'auteur. Cela inclut, mais sans s'y limiter :
# - La publication sur des plateformes publiques,
# - Les forums,
# - Les réseaux sociaux,
# - Les sites de partage de fichiers.
#
# 📚 **Référence**
# Si vous utilisez ce jeu de données dans une publication, merci de citer la source :
# **National Library of Medicine, National Institutes of Health, Bethesda, MD, USA**.
#
# **Violations et Recours**
# Toute violation de ces conditions sera considérée comme une infraction aux droits d'auteur et pourra donner lieu à des poursuites judiciaires.
#
# Pour toute question ou demande concernant l'utilisation du Contenu, veuillez **contacter techdataprojects directement**.
#
#
# ---
#
# ## ⚙️ Configuration de Votre Projet de Deep Learning
#
# Ce guide vous aide à créer et configurer un environnement virtuel pour votre projet de Deep Learning.
# Nous partons du principe que vous utilisez une machine **Windows** avec **Python** et **Visual Studio Code** déjà installés:
# *Si ce n'est pas le cas, veuillez consulter les tutoriels #01, et #02 appropriés pour installer Python et VSCode sous Windows 11.*
#
# ---
#
# ### 🖥️ **Étapes à Suivre :**
#
# 1. **Ajouter le dossier projet à VSCode :**
#    - Ajoutez le dossier `Projet_DeepLearning` dans votre espace de travail Visual Studio Code, puis ouvrez un terminal intégré.
#
# 2. **Créer un environnement virtuel :**
#    - Dans le terminal, exécutez la commande suivante :
#      ```bash
#      python -m venv env_deeplearning
#      ```
#
# 3. **Activer l'environnement virtuel sous Windows :**
#    - D'abord, autorisez l'exécution des scripts si nécessaire (l'exécution de Script est désactivé par défaut sous Windows) :
#      ```bash
#      Set-ExecutionPolicy RemoteSigned -Scope CurrentUser
#      ```
#    - Ensuite, activez l'environnement virtuel :
#      ```bash
#      .\env_deeplearning\Scripts\Activate.ps1
#      ```
#
#    - Si vous êtes sous **UNIX**, activez l'environnement avec cette commande :
#      ```bash
#      source env_deeplearning/bin/activate
#      ```
# 4. **Installer les librairies :**
#    - Dans le terminal, exécutez la commande suivante :
#      ```bash
#      pip install -r requirements.txt
#      ```
#
# ---
#
# # **Votre Environnement est Prêt !** 🎉
#
# Vous pouvez maintenant ouvrir les **Jupyter Notebooks** du projet (fichiers `.ipynb`) depuis votre espace de travail **VSCode**.
# Suivez l'ordre des étapes ci-dessous pour travailler correctement sur chaque partie du projet. Veillez à ouvrir chaque notebook dans l'ordre des étapes pour garantir une progression logique.
#
# ### **Ouvrir les Notebooks dans l'Ordre**
#
# **Étape 0 : Formation Express Python** 📘 **Notebook :** `00_Formation_Express_Python.ipynb`   - Mise à niveau express en Python.
#
# **Étape 1 : Annotation des Images**  📘 **Notebook :** `01_Annotation_images.ipynb`   - Annotation des images et export des données.
#
# **Étape 2 : Création des Masques**  📘 **Notebook :** `02_Creation_masques.ipynb`  - Génération de masques binaires pour les globules blancs.
#
# **Étape 3 : Développement du Modèle CNN**  📘 **Notebook :** `03_WBC_model_CNN.ipynb`  - Construction et entraînement du modèle CNN.
#
# **Étape 4 : Évaluation du Modèle**  📘 **Notebook :** `04_Evaluation_model.ipynb`  - Analyse du résultat de l'entraînement du modèle & test.
#
# **Étape 5 : Application Deep Learning**  📘 **Notebook :** `05_Application_WBC.ipynb`  - Création d'une application de détection.
#
# **Étape 6 : Bonus TensorBoard**  📘 **Notebook :** `06_BONUS_Tensorboard.ipynb`  - Visualisation des performances avec TensorBoard.
#
# ⚠️ Après avoir ouvert chaque notebook, sélectionnez le **kernel** correspondant à votre environnement virtuel de programmation en cliquant sur le bouton **"Select Kernel"** situé en haut à droite de VSCode.
# Le kernel à choisir est celui correspondant à l'environnement que vous venez de créer, à savoir **'env_deeplearning'**.
#
# Bonne exploration du projet et bonne continuation ! 🚀

# %% [markdown]
# # **Les Erreur repertoriés et connues :**
#
# ---
#
# **<span style="color:red;">#01</span> L'erreur DLL msvcp140.dll / msvcp140_1.dll suivante lors de l'utilisation de TensorFlow :**
#
# > ImportError: Could not find the DLL(s) 'msvcp140.dll or msvcp140_1.dll'. TensorFlow requires that these DLLs be installed in a directory that is named in your %PATH% environment variable.
# > You may install these DLLs by downloading "Microsoft C++ Redistributable for Visual Studio 2015, 2017 and 2019" for your platform from this URL: https://support.microsoft.com/help/2977003/
# > the-latest-supported-visual-c-downloads
#
# <u>**Étapes à suivre pour résoudre l'erreur :**</u>
# Cela signifie qu'il vous manque certaines bibliothèques nécessaires pour faire fonctionner TensorFlow. La solution consiste à télécharger et installer le **Microsoft Visual C++ Redistributable**.
#
# 1. **Téléchargez Microsoft Visual C++ Redistributable**
#    Allez sur le lien ci-dessus et téléchargez la version correspondant à votre système.
#
# 2. **Vérifiez l'architecture de votre système**
#    Pour savoir si votre machine est en **64 bits (x64)** ou **32 bits (x86)** :
#    - Appuyez sur **Win + I** pour ouvrir les paramètres.
#    - Allez dans **Système > À propos**.
#    - Sous **Type de système**, vous verrez l'architecture :
#      - **Système d’exploitation 64 bits, processeur x64** (pour un système 64 bits)
#      - **Système d’exploitation 32 bits, processeur x86** (pour un système 32 bits)
#
# Une fois cette information obtenue, téléchargez la version appropriée de **Microsoft Visual C++ Redistributable**.
#
# ---
#
#
#
# <span style="color:red;">**#02</span> Incompatibilité version Numpy <=> Tensorflow**
#
#
# > A module that was compiled using NumPy 1.x cannot be run in
# > NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# > versions of NumPy, modules must be compiled with NumPy 2.0.
# > Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
# > If you are a user of the module, the easiest solution will be to
# > downgrade to 'numpy<2' or try to upgrade the affected module.
# > We expect that some modules will need time to support NumPy 2.
#
# <u>**Étapes à suivre pour résoudre l'erreur :**</u>
# Il faut une version numpy <2 pour tensorflow 2.14. Veuillez installer les librairies aux versions indiquées sur le fichier requirements.txt.
#
# ```
# pip install numpy<2
# ```
# - **Python 3.13** n'est **pas encore compatible** avec **TensorFlow 2.14.0**. Il est donc recommandé de rester sur une version de Python entre **3.9 et 3.12** pour garantir la compatibilité.
# - **pip** : Version **19.0 ou supérieure** pour Linux et Windows. Version **20.3 ou supérieure** pour macOS.
# ---
